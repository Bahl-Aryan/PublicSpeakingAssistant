# %%
import librosa
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True) # mount to google drive
# Out:
# Mounted at /content/gdrive

# %%
audio_files = pd.DataFrame(pd.read_excel("/content/gdrive/MyDrive/222 proj/data.xlsx")) # audio
audio_files
# Out:
#                file_name  assertiveness  enthusiasim  clairity  engagement
# 0      Aaron_Beverly.wav              8            6         9           9
# 1                 b1.wav              3            3         5           2
# 2                 b2.wav              6            7         5           7
# 3              champ.wav              9           10         9          10
# 4            harvard.wav              8            7         8           8
# 5          miss_teen.wav              6            6         2           4
# 6         obama_2020.wav              8            7         9           8
# 7              obama.wav             10            9         9           9
# 8           reporter.wav              7            5         3           4
# 9              socks.wav              4            4         2           3
# 10  Susan_Lozier_TED.wav              7            7         9           8
# 11             toast.wav              9           10         9          10
# 12           trudeau.wav              7            7         9           8
# 13             Woman.wav              7            5         8           5
# 14   trimmed_speech1.wav              8            7        10           8
# 15   trimmed_speech2.wav              7            8         8           8
# 16   trimmed_speech3.wav              3            3         0           2
# 17   trimmed_speech4.wav              8           10         7           8
# 18   trimmed_speech5.wav              6            6         4           5
# 19   trimmed_speech6.wav              2            1         0           1

# %%
def preprocess_data(file_path):
  audio, sr = librosa.load(file_path, sr=16000) #16000 is recommended sample rate for
  mfccs_scaled = np.mean(librosa.feature.mfcc(y=audio, sr = 16000, n_mfcc=1000).T, axis=0)
  return mfccs_scaled

# %%
import tensorflow as tf
mfcc_features_list = [] # list of spectrograms
for file_name in audio_files["file_name"]:
  print(file_name)
  audio = preprocess_data("/content/gdrive/MyDrive/222 proj/audio_clips/" + file_name)
  mfcc_features_list.append(audio) # append spectrogram audio data to audios. After the loop, audios will have the audio information of all the files as a spectrograms in different rows
audio_files.insert(0, "mfccs", mfcc_features_list) # inserting new audio column to audio_files
# Out:
# Aaron_Beverly.wav
# b1.wav
# b2.wav
# champ.wav
# harvard.wav
# miss_teen.wav
# obama_2020.wav
# obama.wav
# reporter.wav
# socks.wav
# Susan_Lozier_TED.wav
# toast.wav
# trudeau.wav
# Woman.wav
# trimmed_speech1.wav
# trimmed_speech2.wav
# trimmed_speech3.wav
# trimmed_speech4.wav
# trimmed_speech5.wav
# trimmed_speech6.wav

# %%
audio_files.head() # check what audio_files looks like
# Out:
#                                                mfccs          file_name  \
# 0  [-355.01233, 80.249466, -18.828096, 16.806034,...  Aaron_Beverly.wav
# 1  [-176.20737, 65.394585, -16.727531, 17.33147, ...             b1.wav
# 2  [-377.40625, 90.72757, 5.678156, 7.091702, -3....             b2.wav
# 3  [-236.3935, 67.31595, -19.487085, 20.926512, -...          champ.wav
# 4  [-306.0925, 125.22217, -57.953915, 22.362713, ...        harvard.wav
#
#    assertiveness  enthusiasim  clairity  engagement
# 0              8            6         9           9
# 1              3            3         5           2
# 2              6            7         5           7
# 3              9           10         9          10
# 4              8            7         8           8

# %%
import seaborn
from scipy import stats

quality = "enthusiasim" # THIS IS WHERE TO CHOOSE WHICH QUALITY WE WANT TO TRAIN THE MODEL ON
seaborn.histplot(data=audio_files[quality])
# Out:
# <Axes: xlabel='enthusiasim', ylabel='Count'>

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(audio_files['mfccs'], audio_files[quality], test_size=0.25, random_state=48) # split into 80% 20% training testing datasets

# %%
y_train
# Out:
# 12     7
# 18     6
# 3     10
# 11    10
# 10     7
# 13     5
# 15     8
# 2      7
# 14     7
# 6      7
# 19     1
# 16     3
# 4      7
# 17    10
# 0      6
# Name: enthusiasim, dtype: int64

# %%
from tensorflow.python.framework import ops
# convert training and testing data lists into np array
x_train = np.asarray(x_train)
x_test = np.asarray(x_test)
y_train = np.asarray(y_train)
y_test = np.asarray(y_test)
# convert to tensor
x_train = np.array([tensor for tensor in x_train])
x_test = np.array([tensor for tensor in x_test])

# %%
x_train
# Out:
# array([[-2.77636414e+02,  7.15413284e+01, -1.00358715e+01, ...,
#          5.21517992e-02,  1.83672681e-01, -6.13887832e-02],
#        [-1.56140701e+02,  8.24230499e+01, -1.07907190e+01, ...,
#         -1.56039804e-01, -1.36739746e-01, -4.98815924e-02],
#        [-2.36393494e+02,  6.73159485e+01, -1.94870853e+01, ...,
#          1.42657816e-01,  8.18222091e-02,  1.48783159e-03],
#        ...,
#        [-3.06092499e+02,  1.25222168e+02, -5.79539146e+01, ...,
#         -2.86366463e-01, -6.82234824e-01, -1.11428715e-01],
#        [-1.94206009e+02,  7.54548645e+01,  5.43860006e+00, ...,
#          2.98197210e-01,  8.14174265e-02, -1.19373150e-01],
#        [-3.55012329e+02,  8.02494659e+01, -1.88280964e+01, ...,
#          1.46538168e-02, -1.50094911e-01,  2.49945149e-02]], dtype=float32)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Conv1D, MaxPooling1D

# create model
model = Sequential()
model.add(Dense(100, activation='relu'))

model.add(Dense(1, activation='relu'))

# %%
x_train
# Out:
# array([[-2.77636414e+02,  7.15413284e+01, -1.00358715e+01, ...,
#          5.21517992e-02,  1.83672681e-01, -6.13887832e-02],
#        [-1.56140701e+02,  8.24230499e+01, -1.07907190e+01, ...,
#         -1.56039804e-01, -1.36739746e-01, -4.98815924e-02],
#        [-2.36393494e+02,  6.73159485e+01, -1.94870853e+01, ...,
#          1.42657816e-01,  8.18222091e-02,  1.48783159e-03],
#        ...,
#        [-3.06092499e+02,  1.25222168e+02, -5.79539146e+01, ...,
#         -2.86366463e-01, -6.82234824e-01, -1.11428715e-01],
#        [-1.94206009e+02,  7.54548645e+01,  5.43860006e+00, ...,
#          2.98197210e-01,  8.14174265e-02, -1.19373150e-01],
#        [-3.55012329e+02,  8.02494659e+01, -1.88280964e+01, ...,
#          1.46538168e-02, -1.50094911e-01,  2.49945149e-02]], dtype=float32)

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mae', 'mse'])

# train the model
history = model.fit(x_train, y_train, epochs = 100, validation_data=[x_test, y_test])
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 846ms/step - loss: 6.9870 - mae: 1.9007 - mse: 6.9870 - val_loss: 6.8881 - val_mae: 1.9972 - val_mse: 6.8881
# Epoch 2/100
# 1/1 [==============================] - 0s 59ms/step - loss: 24.8679 - mae: 4.5204 - mse: 24.8679 - val_loss: 10.1873 - val_mae: 2.7166 - val_mse: 10.1873
# Epoch 3/100
# 1/1 [==============================] - 0s 44ms/step - loss: 6.0524 - mae: 1.8532 - mse: 6.0524 - val_loss: 19.2822 - val_mae: 4.2928 - val_mse: 19.2822
100
# 1/1 [==============================] - 0s 76ms/step - loss: 0.3003 - mae: 0.3305 - mse: 0.3003 - val_loss: 5.5766 - val_mae: 1.7177 - val_mse: 5.5766
# Epoch 79/100
# 1/1 [==============================] - 0s 95ms/step - loss: 0.2883 - mae: 0.3094 - mse: 0.2883 - val_loss: 5.6627 - val_mae: 1.7265 - val_mse: 5.6627
# Epoch 80/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.2820 - mae: 0.2918 - mse: 0.2820 - val_loss: 5.6813 - val_mae: 1.7276 - val_mse: 5.6813
# Epoch 81/100
# 1/1 [==============================] - 0s 82ms/step - loss: 0.2763 - mae: 0.2869 - mse: 0.2763 - val_loss: 5.6063 - val_mae: 1.7174 - val_mse: 5.6063
# Epoch 82/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.2667 - mae: 0.2835 - mse: 0.2667 - val_loss: 5.4748 - val_mae: 1.6998 - val_mse: 5.4748
# Epoch 83/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.2568 - mae: 0.2852 - mse: 0.2568 - val_loss: 5.3514 - val_mae: 1.6822 - val_mse: 5.3514
# Epoch 84/100
# 1/1 [==============================] - 0s 87ms/step - loss: 0.2505 - mae: 0.2923 - mse: 0.2505 - val_loss: 5.2887 - val_mae: 1.6721 - val_mse: 5.2887
# Epoch 85/100
# 1/1 [==============================] - 0s 80ms/step - loss: 0.2444 - mae: 0.2938 - mse: 0.2444 - val_loss: 5.2973 - val_mae: 1.6715 - val_mse: 5.2973
# Epoch 86/100
# 1/1 [==============================] - 0s 76ms/step - loss: 0.2360 - mae: 0.2821 - mse: 0.2360 - val_loss: 5.3442 - val_mae: 1.6761 - val_mse: 5.3442
# Epoch 87/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.2275 - mae: 0.2663 - mse: 0.2275 - val_loss: 5.3657 - val_mae: 1.6770 - val_mse: 5.3657
# Epoch 88/100
# 1/1 [==============================] - 0s 71ms/step - loss: 0.2209 - mae: 0.2566 - mse: 0.2209 - val_loss: 5.3502 - val_mae: 1.6729 - val_mse: 5.3502
# Epoch 89/100
# 1/1 [==============================] - 0s 82ms/step - loss: 0.2149 - mae: 0.2513 - mse: 0.2149 - val_loss: 5.2881 - val_mae: 1.6626 - val_mse: 5.2881
# Epoch 90/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2075 - mae: 0.2490 - mse: 0.2075 - val_loss: 5.2017 - val_mae: 1.6486 - val_mse: 5.2017
# Epoch 91/100
# 1/1 [==============================] - 0s 90ms/step - loss: 0.2006 - mae: 0.2517 - mse: 0.2006 - val_loss: 5.1292 - val_mae: 1.6365 - val_mse: 5.1292
# Epoch 92/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.1950 - mae: 0.2547 - mse: 0.1950 - val_loss: 5.0980 - val_mae: 1.6302 - val_mse: 5.0980
# Epoch 93/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1891 - mae: 0.2525 - mse: 0.1891 - val_loss: 5.1095 - val_mae: 1.6304 - val_mse: 5.1095
# Epoch 94/100
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1824 - mae: 0.2437 - mse: 0.1824 - val_loss: 5.1449 - val_mae: 1.6341 - val_mse: 5.1449
# Epoch 95/100
# 1/1 [==============================] - 0s 83ms/step - loss: 0.1761 - mae: 0.2320 - mse: 0.1761 - val_loss: 5.1768 - val_mae: 1.6375 - val_mse: 5.1768
# Epoch 96/100
# 1/1 [==============================] - 0s 77ms/step - loss: 0.1706 - mae: 0.2236 - mse: 0.1706 - val_loss: 5.1785 - val_mae: 1.6365 - val_mse: 5.1785
# Epoch 97/100
# 1/1 [==============================] - 0s 90ms/step - loss: 0.1652 - mae: 0.2188 - mse: 0.1652 - val_loss: 5.1441 - val_mae: 1.6302 - val_mse: 5.1441
# Epoch 98/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1592 - mae: 0.2171 - mse: 0.1592 - val_loss: 5.0971 - val_mae: 1.6217 - val_mse: 5.0971
# Epoch 99/100
# 1/1 [==============================] - 0s 85ms/step - loss: 0.1538 - mae: 0.2178 - mse: 0.1538 - val_loss: 5.0697 - val_mae: 1.6159 - val_mse: 5.0697
# Epoch 100/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1491 - mae: 0.2187 - mse: 0.1491 - val_loss: 5.0753 - val_mae: 1.6153 - val_mse: 5.0753

# %%
y_pred = model.predict(x_test)
# Out:
# 1/1 [==============================] - 0s 56ms/step

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test, y_pred))
# Out:
# -0.1970130574420792

# %%
for y in range(0, len(y_pred)):
  print("Actual Enthusiasm", y_test[y], "Predicted enthusiasm:", y_pred[y][0])
# Out:
# Actual Enthusiasm 3 Predicted enthusiasm: 3.8643587
# Actual Enthusiasm 4 Predicted enthusiasm: 3.6078587
# Actual Enthusiasm 6 Predicted enthusiasm: 5.272105
# Actual Enthusiasm 9 Predicted enthusiasm: 10.404229
# Actual Enthusiasm 5 Predicted enthusiasm: 0.31234646

# %%
from scipy.stats import spearmanr
coef, p = spearmanr(y_test, y_pred)
print(coef)
# Out:
# nan
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))

# %%
# !mkdir saved_model
model.save("saved_models/" + quality) # create ability to save model for any quality

# %%
# !zip -r "saved_models.zip" "saved_models"
# Out:
#   adding: saved_models/ (stored 0%)
#   adding: saved_models/enthusiasim/ (stored 0%)
#   adding: saved_models/enthusiasim/fingerprint.pb (stored 0%)
#   adding: saved_models/enthusiasim/variables/ (stored 0%)
#   adding: saved_models/enthusiasim/variables/variables.data-00000-of-00001 (deflated 8%)
#   adding: saved_models/enthusiasim/variables/variables.index (deflated 64%)
#   adding: saved_models/enthusiasim/saved_model.pb (deflated 87%)
#   adding: saved_models/enthusiasim/keras_metadata.pb (deflated 90%)
#   adding: saved_models/enthusiasim/assets/ (stored 0%)

# %%
# after saving all different models...

# %%
def test_speech(file_name, characteristic):
  if characteristic not in ("assertiveness", "enthusiasm", "clarity", "engagement"):
    print("Error: test_speech called with bad characteristic. Please use one of the following: assertiveness, enthusiasm, clarity, engagement")
    return -1

  model = tf.keras.models.load_model('saved_models/' + quality) # load in saved model

  spectrogram = get_spectrogram("/content/gdrive/MyDrive/222 proj/audio_clips/" + file_name)
  spectrogram = spectrogram[0:15000] # cut to 30 seconds
  return model.predict(spectrogram) # return prediction
